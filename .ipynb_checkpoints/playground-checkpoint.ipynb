# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
from shapely.geometry import Polygon

from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LogisticRegression
import pysal as ps
from spacv.grid_builder import *
from spacv.spacv import cross_val_score
import spacv
from sklearn.neighbors import KDTree

# %%
df = gpd.read_file('/opt/conda/lib/python3.7/site-packages/libpysal/examples/baltim/baltim.shp')

XYs = df['geometry']
X = df[['NROOM', 'DWELL', 'NBATH']]
y = df['PATIO']

model = LinearRegression(fit_intercept=True)

# %%
test.to_csv('test.csv',index=False)
train.to_csv('train.csv',index=False)

# %%
def aoa(test_data, training_data, model=None, variables='all', thres=0.95):
    
    if len(training_data) <= 1:
        raise Exception('At least two training instances need to be specified.') 
    
    # Scale data and weight if applicable
    training_data = (training_data - np.mean(training_data)) / np.std(training_data)
    test_data = (test_data - np.mean(test_data)) / np.std(test_data)

    tree = KDTree(training_data, metric='euclidean') 
    mindist, _ = tree.query(test_data, k=1, return_distance=True)

    paired_distances = pdist(training_data)
    train_dist = squareform(paired_distances)

    train_dist_mean = train_dist.mean(axis=1)
    train_dist_avgmean = np.mean(train_dist_mean)


    mindist = mindist / train_dist_avgmean

    # Set diagonal nan to exclude from average
    np.fill_diagonal(train_dist, np.nan)

    # Define threshold for AOA
    train_dist_min = np.nanmin(train_dist, axis=1)
    aoa_train_stats = np.percentile(train_dist_min / train_dist_avgmean, 
                                    q = np.array([0.25, 0.5, 0.75, 0.9, 0.95, 0.99, 1]))
    thres = np.percentile(train_dist_min / train_dist_avgmean, q = thres)

    # We choose the AOA as the area where the DI does not exceed the threshold
    out = mindist.reshape(-1)
    masked_result = np.repeat(1, len(mindist))
    masked_result[out > thres] = 0
    
    return out, masked_result

# %%
training_data = train[['PRICE', 'NROOM', 'LOTSZ', 'SQFT']]
test_data = test[['PRICE', 'NROOM', 'LOTSZ', 'SQFT']]

# %%
out, masked_result = aoa(test_data, training_data, thres=.99)

# %%
test['aoa'] = out
test['mask'] = masked_result

# %%
test = test.join(df, lsuffix='_')

# %%
test = gpd.GeoDataFrame(test, geometry=test.geometry)

# %%
f,ax = plt.subplots(1, 2, figsize=(12,8))
df.loc[train.index].plot(ax=ax[0], alpha=.3)
test.plot(ax=ax[0], column='aoa', legend=True, cmap='viridis', legend_kwds={'shrink': 0.4})

df.loc[train.index].plot(ax=ax[1], alpha=.3)
test.plot(ax=ax[1], column='mask',legend=True, categorical=True, cmap='Set1')


ax[0].set_title('Dissimilarity index (DI)')
ax[1].set_title('AOA');

# %%
cv = spacv.HBLOCK(buffer_radius=0, method='random')

# %%
scores = cross_val_score(model, XYs, X, y, cv, mean_squared_error)

# %%
np.sqrt(
    np.mean(scores)
)
# Out:
# 0.12009104502919782

# %%
class UserDefinedSCV(BaseSpatialCV):
    
    def __init__(
        self,
        customshape,
        buffer_radius = None
    ):
        self.customshape = customshape
        self.buffer_radius = buffer_radius
        
        
    def _iter_test_indices(self, X):
        
        customshape = self.customshape
        
        for grid_id in customshape:

            yield test_points, hblock_train_exclude

# %%
UserDefinedSCV(user_supplied)

# %%
f,ax=plt.subplots(1)
user_supplied.plot(ax=ax)
df.plot(ax=ax)

# %%
a = df.sample(3).geometry.unary_union.convex_hull

b = df.sample(3).geometry.unary_union.convex_hull

c = df.sample(3).geometry.unary_union.convex_hull

# %%
from shapely.geometry import MultiPolygon

# %%
user_supplied = gpd.GeoDataFrame({'geometry':MultiPolygon([a,b,c])})

# %%
f, ax = plt.subplots(1)
blocks(df, tiles_x=3, tiles_y=5, method='unique').plot(column='grid_id', cmap='Greens',ax=ax)
df.plot(ax=ax, color='black')

# %%
f, ax = plt.subplots(1)
blocks(df, method='systematic', tiles_x=7, tiles_y=5, direction='anti').plot(column='grid_id', cmap='Set1', ax=ax)
df.plot(ax=ax, color='black')

# %%
f, ax = plt.subplots(1)
blocks(df, method='randomized', tiles_x=5, tiles_y=5, n_groups=3).plot(column='grid_id', ax=ax)
df.plot(ax=ax, color='black')

# %%
from sklearn.cluster import KMeans

# %%
xys = df.geometry.centroid
xys = np.array(list(map(lambda x : (x.x, x.y), xys)))

k = xys.shape[0]
km = KMeans(n_clusters=k).fit(xys)

# %%
df['label'] = km.labels_

# %%
f, ax = plt.subplots(1, figsize=(8,8))
ax.axis('off')
df.plot(column='label', ax=ax)
